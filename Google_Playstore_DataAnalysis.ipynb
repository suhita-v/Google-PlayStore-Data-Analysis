# %%
# Installing Textblob to perform Sentiment Analysis
pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob in /usr/local/lib/python3.8/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.8/dist-packages (from textblob) (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->textblob) (4.64.1)

# %%
# Importing necessary libraries and packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob

# %%
# Readind the csv file as df
df = pd.read_csv('playstore_apps.csv')

# %%
# Displaying Top 5 rows of Dataset
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size    Installs  Type  Price Content Rating  \
# 0     159.0   19M     10000.0  Free    0.0       Everyone
# 1     967.0   14M    500000.0  Free    0.0       Everyone
# 2   87510.0  8.7M   5000000.0  Free    0.0       Everyone
# 3  215644.0   25M  50000000.0  Free    0.0           Teen
# 4     967.0  2.8M    100000.0  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   07-01-2018               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play   15-01-2018               2.0.0  4.0.3 and up
# 2               Art & Design   01-08-2018               1.2.4  4.0.3 and up
# 3               Art & Design   08-06-2018  Varies with device    4.2 and up
# 4    Art & Design;Creativity   20-06-2018                 1.1    4.4 and up

# %%
# Finding the total number of Rows and Columns in Dataset
df.shape
# Out:
# (10841, 13)

# %%
# Getting a description of the Dataset
df.describe()
# Out:
#             Rating       Reviews      Installs         Price
# count  9367.000000  1.084000e+04  1.084000e+04  10840.000000
# mean      4.193338  4.441529e+05  1.546434e+07      1.027368
# std       0.537431  2.927761e+06  8.502936e+07     15.949703
# min       1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04  5.000000e+06      0.000000
# max      19.000000  7.815831e+07  1.000000e+09    400.000000

# %%
# Creating a boxplot to identify possible outliers
df.boxplot(column='Rating')

# %%
# Creating a histogram to cross check for the same
df.hist(column='Rating');

# %% [markdown]
# ##**Data Cleaning and Preparation**

# %%
# Getting information on the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.1+ MB

# %%
#Checking for null values
df.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# 0               False   False         False        False        False
# 1               False   False         False        False        False
# 2               False   False         False        False        False
# 3               False   False         False        False        False
# 4               False   False         False        False        False
# ...               ...     ...           ...          ...          ...
# 10836           False   False         False        False        False
# 10837           False   False         False        False        False
# 10838           False   False         False        False        False
# 10839           False   False         False        False        False
# 10840           False   False         False        False        False
#
# [10841 rows x 13 columns]

# %%
#Checking for Null values
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              1
# Size                 0
# Installs             1
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         1
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# Checking how many outliers are present
df[df.Rating>5]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0      NaN
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+       NaN    0    NaN            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaN  4.0 and up         NaN

# %%
# Dropping the Outlier we found
df.drop([10472], inplace=True)

# %%
# Checking the Dataset for null values
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
# Checking if the dropped outlier has been dropped successfully
df[10470:10475]
# Out:
#                            App         Category  Rating   Reviews  Size  \
# 10470               Jazz Wi-Fi    COMMUNICATION     3.4      49.0  4.0M
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042.0  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203.0  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37.0   14M
# 10475         Wi-Fi Visualizer            TOOLS     3.9     132.0  2.6M
#
#          Installs  Type  Price Content Rating           Genres Last Updated  \
# 10470     10000.0  Free    0.0       Everyone    Communication   10-02-2017
# 10471    100000.0  Free    0.0       Everyone  Personalization   05-08-2014
# 10473  10000000.0  Free    0.0       Everyone            Tools   07-08-2018
# 10474      1000.0  Free    0.0       Everyone    Communication   21-11-2014
# 10475     50000.0  Free    0.0       Everyone            Tools   17-05-2017
#
#       Current Ver   Android Ver
# 10470         0.1    2.3 and up
# 10471       3.0.0  4.0.3 and up
# 10473     6.06.14    4.4 and up
# 10474     2.2.1.5    2.2 and up
# 10475       0.0.9    2.3 and up

# %%
# Reconfirming to check for any other outlier
df.boxplot(column='Rating')

# %%
# Cross checking again for the same
df.hist(column='Rating')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff7c9696790>]],
#       dtype=object)

# %%
# Dropping columns irrelevant to analysis
df.drop(['Current Ver', 'Android Ver'], axis=1, inplace= True)

# %%
# Finding the null values in column "Type"
df[df.Type.isnull()]
# Out:
#                             App Category  Rating  Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN      0.0  Varies with device
#
#       Installs Type  Price Content Rating    Genres Last Updated
# 9148       0.0  NaN    0.0   Everyone 10+  Strategy   28-06-2018

# %%
# Filling the missing value with 'Free' as the price is 0.0
df['Type'].fillna("Free", inplace = True)

# %%
# Checking again for null values in the Dataset
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# dtype: int64

# %%
# Replacing the missing values in 'Rating' with the mode value of that entire column since there are 1474 null values
modeValueRating = df['Rating'].mode()

# %%
# Replacing the null values in 'Rating' with the Mode Value of Rating Found above
df['Rating'].fillna(value = modeValueRating[0], inplace = True)

# %%
# Checking for null values to see if any more null values are present in the Dataset
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# dtype: int64

# %%
# Removing the special characters and changing the data type of 'Size' column

# Removing the + symbol
df['Size'] = df.Size.apply(lambda x: x.strip('+'))

# %%
# Removing the ; symbol
df['Size'] = df.Size.apply(lambda x: x.replace(',' , ''))

# %%
# Removing the 'M' symbol and multipyling the value with 1000000
df['Size'] = df.Size.apply(lambda x: x.replace('M' , 'e+6'))

# %%
# Removing the 'K' symbol and multiplying the value with 1000
df['Size'] = df.Size.apply(lambda x: x.replace('k' , 'e+3'))

# %%
# Replacing the 'Varies with device' values with Nan
df['Size'] = df.Size.replace('Varies with device' , np.NaN)

# %%
# Checking for null values in the Dataset
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating               0
# Reviews              0
# Size              1695
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# dtype: int64

# %%
# Dropping null values in 'Size'
df.dropna(subset = ['Size'], inplace = True)

# %%
# Checking if the null values in 'Size' are dropped correctly and any other null values present in the Dataset
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# dtype: int64

# %%
# Converting the data type of 'Size' from object to numeric
df['Size'] = pd.to_numeric(df['Size'])

# %%
# Getting information on the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9145 entries, 0 to 10840
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9145 non-null   object
#  1   Category        9145 non-null   object
#  2   Rating          9145 non-null   float64
#  3   Reviews         9145 non-null   float64
#  4   Size            9145 non-null   float64
#  5   Installs        9145 non-null   float64
#  6   Type            9145 non-null   object
#  7   Price           9145 non-null   float64
#  8   Content Rating  9145 non-null   object
#  9   Genres          9145 non-null   object
#  10  Last Updated    9145 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 857.3+ KB

# %%
# Changing the data type of 'Reviews' and 'Installs' from float to int
df = df.astype({"Reviews":int})

# %%
# Changing the data type of 'Reviews' and 'Installs' from float to int
df = df.astype({"Installs":int})

# %%
# Getting information on the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9145 entries, 0 to 10840
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9145 non-null   object
#  1   Category        9145 non-null   object
#  2   Rating          9145 non-null   float64
#  3   Reviews         9145 non-null   int64
#  4   Size            9145 non-null   float64
#  5   Installs        9145 non-null   int64
#  6   Type            9145 non-null   object
#  7   Price           9145 non-null   float64
#  8   Content Rating  9145 non-null   object
#  9   Genres          9145 non-null   object
#  10  Last Updated    9145 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 857.3+ KB

# %%
# Printing Unique Values in 'Category'
print(df['Category'].unique())
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']

# %%
# Storing the duplicate values in 'App' into "duplicates"
duplicates = df[df.duplicated(['App'])]

# %%
# Printing the duplicates
print(duplicates)
# Out:
#                                       App       Category  Rating  Reviews  \
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 266                              Zenefits       BUSINESS     4.2      296
# 267                            Google Ads       BUSINESS     4.3    29313
# 270                    FreshBooks Classic       BUSINESS     4.1     1802
# 271                         Insightly CRM       BUSINESS     3.8     1383
# ...                                   ...            ...     ...      ...
# 10715                  FarmersOnly Dating         DATING     3.0     1145
# 10720  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10730                         FP Notebook        MEDICAL     4.5      410
# 10753      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10768                                AAFP        MEDICAL     3.8       63
#
#              Size  Installs  Type  Price Content Rating         Genres  \
# 256    37000000.0  10000000  Free    0.0       Everyone       Business
# 266    14000000.0     50000  Free    0.0       Everyone       Business
# 267    20000000.0   5000000  Free    0.0       Everyone       Business
# 270    26000000.0    100000  Free    0.0       Everyone       Business
# 271    51000000.0    100000  Free    0.0       Everyone       Business
# ...           ...       ...   ...    ...            ...            ...
# 10715   1400000.0    100000  Free    0.0     Mature 17+         Dating
# 10720   4000000.0   1000000  Free    0.0       Everyone  Communication
# 10730  60000000.0     50000  Free    0.0       Everyone        Medical
# 10753  12000000.0   1000000  Free    0.0       Everyone       Shopping
# 10768  24000000.0     10000  Free    0.0       Everyone        Medical
#
#       Last Updated
# 256     20-07-2018
# 266     15-06-2018
# 267     30-07-2018
# 270     18-04-2018
# 271     12-07-2018
# ...            ...
# 10715   25-02-2016
# 10720   06-07-2018
# 10730   24-03-2018
# 10753   30-07-2018
# 10768   22-06-2018
#
# [711 rows x 11 columns]

# %%
# Removing the duplicate values
df.drop_duplicates(keep=False, inplace=True)
df
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#        Rating  Reviews        Size  Installs  Type  Price Content Rating  \
# 0         4.1      159  19000000.0     10000  Free    0.0       Everyone
# 1         3.9      967  14000000.0    500000  Free    0.0       Everyone
# 2         4.7    87510   8700000.0   5000000  Free    0.0       Everyone
# 3         4.5   215644  25000000.0  50000000  Free    0.0           Teen
# 4         4.3      967   2800000.0    100000  Free    0.0       Everyone
# ...       ...      ...         ...       ...   ...    ...            ...
# 10835     4.4        0   9600000.0        10  Free    0.0       Everyone
# 10836     4.5       38  53000000.0      5000  Free    0.0       Everyone
# 10837     5.0        4   3600000.0       100  Free    0.0       Everyone
# 10838     4.4        3   9500000.0      1000  Free    0.0       Everyone
# 10840     4.5   398307  19000000.0  10000000  Free    0.0       Everyone
#
#                           Genres Last Updated
# 0                   Art & Design   07-01-2018
# 1      Art & Design;Pretend Play   15-01-2018
# 2                   Art & Design   01-08-2018
# 3                   Art & Design   08-06-2018
# 4        Art & Design;Creativity   20-06-2018
# ...                          ...          ...
# 10835                   Business   29-09-2016
# 10836                  Education   25-07-2017
# 10837                  Education   06-07-2018
# 10838                    Medical   20-01-2017
# 10840                  Lifestyle   25-07-2018
#
# [8556 rows x 11 columns]

# %%
# Getting information on the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8556 entries, 0 to 10840
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8556 non-null   object
#  1   Category        8556 non-null   object
#  2   Rating          8556 non-null   float64
#  3   Reviews         8556 non-null   int64
#  4   Size            8556 non-null   float64
#  5   Installs        8556 non-null   int64
#  6   Type            8556 non-null   object
#  7   Price           8556 non-null   float64
#  8   Content Rating  8556 non-null   object
#  9   Genres          8556 non-null   object
#  10  Last Updated    8556 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 802.1+ KB

# %%
# Checking for Unique values in 'App'
print(df['App'].unique())
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Fr. Mike Schmitz Audio Teachings' 'Parkinson Exercices FR'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']

# %%
# Checking for Unique values in 'Price'
print(df['Price'].unique())
# Out:
# [  0.     6.99   1.49   2.99   3.99   7.99   5.99   4.99   1.99   9.99
#    0.99   1.     3.49  10.99   7.49   1.5   14.99  15.99  74.99  39.99
#   29.99   4.49   1.7    2.     3.88  25.99 399.99  17.99 400.     2.49
#    3.02   1.76   4.84   4.77   1.61  19.99   1.59   6.49   1.29   5.
#   13.99 299.99 379.99  37.99  18.99 389.99  19.9    8.49   1.75  14.
#    4.85  46.99 109.99 154.99   3.08   2.59   4.8    8.99   1.96  19.4
#   15.46  10.     5.49   3.04  12.99   4.29   2.6    3.28   4.6   28.99
#    2.9    1.97  24.99 200.    89.99   2.56  30.99   3.61 394.99   1.26
#   16.99   1.2    1.04]

# %%
# Checking for Unique values in 'Rating'
print(df['Rating'].unique())
# Out:
# [4.1 3.9 4.7 4.5 4.3 4.4 3.8 4.2 4.6 3.2 4.  4.8 4.9 3.6 3.7 3.3 3.4 3.5
#  3.1 5.  2.6 3.  2.5 1.  1.9 2.9 2.8 2.3 2.2 1.7 2.  1.8 2.7 2.4 1.6 2.1
#  1.4 1.5 1.2]

# %%
# Checking for Unique values in 'Reviews'
print(df['Reviews'].unique())
# Out:
# [   159    967  87510 ...    603   1195 398307]

# %%
# Checking for Unique values in 'Size'
print(df['Size'].unique())
# Out:
# [1.90e+07 1.40e+07 8.70e+06 2.50e+07 2.80e+06 5.60e+06 2.90e+07 3.30e+07
#  3.10e+06 2.80e+07 1.20e+07 2.00e+07 2.10e+07 3.70e+07 2.70e+06 5.50e+06
#  1.70e+07 3.90e+07 3.10e+07 4.20e+06 7.00e+06 2.30e+07 6.00e+06 6.10e+06
#  4.60e+06 9.20e+06 5.20e+06 1.10e+07 2.40e+07 9.40e+06 1.50e+07 1.00e+07
#  1.20e+06 2.60e+07 8.00e+06 7.90e+06 5.60e+07 5.70e+07 3.50e+07 5.40e+07
#  2.01e+05 3.60e+06 5.70e+06 8.60e+06 2.40e+06 2.70e+07 2.50e+06 1.60e+07
#  3.40e+06 8.90e+06 3.90e+06 2.90e+06 3.80e+07 3.20e+07 5.40e+06 1.80e+07
#  1.10e+06 2.20e+06 4.50e+06 9.80e+06 5.20e+07 9.00e+06 6.70e+06 3.00e+07
#  2.60e+06 7.10e+06 3.70e+06 2.20e+07 7.40e+06 6.40e+06 3.20e+06 8.20e+06
#  9.90e+06 4.90e+06 9.50e+06 5.00e+06 5.90e+06 1.30e+07 7.30e+07 6.80e+06
#  3.50e+06 4.00e+06 2.30e+06 7.20e+06 2.10e+06 4.20e+07 7.30e+06 9.10e+06
#  5.50e+07 2.30e+04 6.50e+06 1.50e+06 7.50e+06 4.60e+07 8.30e+06 4.30e+06
#  4.70e+06 3.30e+06 4.00e+07 7.80e+06 8.80e+06 6.60e+06 5.10e+06 6.10e+07
#  6.60e+07 7.90e+04 8.40e+06 1.18e+05 4.40e+07 6.95e+05 1.60e+06 6.20e+06
#  1.80e+04 5.30e+07 1.40e+06 3.00e+06 5.80e+06 3.80e+06 9.60e+06 4.50e+07
#  6.30e+07 4.90e+07 4.40e+06 7.00e+07 6.90e+06 9.30e+06 8.10e+06 3.60e+07
#  4.10e+07 5.10e+07 8.40e+07 9.70e+07 2.00e+06 1.90e+06 1.80e+06 5.30e+06
#  4.80e+07 4.70e+07 5.56e+05 5.26e+05 7.60e+07 7.60e+06 5.90e+07 9.70e+06
#  7.80e+07 8.50e+06 7.20e+07 4.30e+07 7.70e+06 7.70e+07 6.30e+06 3.34e+05
#  3.40e+07 9.30e+07 6.50e+07 7.90e+07 1.00e+08 5.80e+07 5.00e+07 6.80e+07
#  6.40e+07 9.40e+07 2.32e+05 9.90e+07 6.24e+05 9.50e+07 8.50e+03 4.10e+04
#  2.92e+05 1.10e+04 8.00e+07 1.70e+06 6.70e+07 7.40e+07 6.20e+07 6.90e+07
#  7.50e+07 8.50e+07 8.20e+07 9.60e+07 8.70e+07 6.00e+07 7.10e+07 9.80e+07
#  8.60e+07 9.10e+07 8.10e+07 9.20e+07 8.30e+07 8.80e+07 8.62e+05 8.99e+05
#  3.78e+05 2.66e+05 3.75e+05 1.30e+06 9.75e+05 9.80e+05 4.10e+06 8.90e+07
#  6.96e+05 5.44e+05 5.25e+05 9.20e+05 7.79e+05 8.53e+05 7.20e+05 7.13e+05
#  4.80e+06 7.72e+05 3.18e+05 5.80e+04 2.41e+05 1.96e+05 8.57e+05 5.10e+04
#  9.53e+05 8.65e+05 2.51e+05 9.30e+05 5.40e+05 3.13e+05 7.46e+05 2.03e+05
#  2.60e+04 3.14e+05 2.39e+05 3.71e+05 2.20e+05 7.30e+05 7.56e+05 9.10e+04
#  2.93e+05 1.70e+04 7.40e+04 1.40e+04 3.17e+05 7.80e+04 9.24e+05 9.02e+05
#  8.18e+05 8.10e+04 9.39e+05 1.69e+05 4.50e+04 4.75e+05 9.65e+05 9.00e+07
#  5.45e+05 6.10e+04 2.83e+05 6.55e+05 7.14e+05 9.30e+04 8.72e+05 1.21e+05
#  3.22e+05 1.00e+06 9.76e+05 1.72e+05 2.38e+05 5.49e+05 2.06e+05 9.54e+05
#  4.44e+05 7.17e+05 2.10e+05 6.09e+05 3.08e+05 7.05e+05 3.06e+05 9.04e+05
#  4.73e+05 1.75e+05 3.50e+05 3.83e+05 4.54e+05 4.21e+05 7.00e+04 8.12e+05
#  4.42e+05 8.42e+05 4.17e+05 4.12e+05 4.59e+05 4.78e+05 3.35e+05 7.82e+05
#  7.21e+05 4.30e+05 4.29e+05 1.92e+05 2.00e+05 4.60e+05 7.28e+05 4.96e+05
#  8.16e+05 4.14e+05 5.06e+05 8.87e+05 6.13e+05 2.43e+05 5.69e+05 7.78e+05
#  6.83e+05 5.92e+05 3.19e+05 1.86e+05 8.40e+05 6.47e+05 1.91e+05 3.73e+05
#  4.37e+05 5.98e+05 7.16e+05 5.85e+05 9.82e+05 2.22e+05 2.19e+05 5.50e+04
#  9.48e+05 3.23e+05 6.91e+05 5.11e+05 9.51e+05 9.63e+05 2.50e+04 5.54e+05
#  3.51e+05 2.70e+04 8.20e+04 2.08e+05 9.13e+05 5.14e+05 5.51e+05 2.90e+04
#  1.03e+05 8.98e+05 7.43e+05 1.16e+05 1.53e+05 2.09e+05 3.53e+05 4.99e+05
#  1.73e+05 5.97e+05 8.09e+05 1.22e+05 4.11e+05 4.00e+05 8.01e+05 7.87e+05
#  2.37e+05 5.00e+04 6.43e+05 9.86e+05 9.70e+04 5.16e+05 8.37e+05 7.80e+05
#  9.61e+05 2.69e+05 2.00e+04 4.98e+05 6.00e+05 7.49e+05 6.42e+05 8.81e+05
#  7.20e+04 6.56e+05 6.01e+05 2.21e+05 2.28e+05 1.08e+05 9.40e+05 1.76e+05
#  3.30e+04 6.63e+05 3.40e+04 9.42e+05 2.59e+05 1.64e+05 4.58e+05 2.45e+05
#  6.29e+05 2.80e+04 2.88e+05 7.75e+05 7.85e+05 6.36e+05 9.16e+05 9.94e+05
#  3.09e+05 4.85e+05 9.14e+05 9.03e+05 6.08e+05 5.00e+05 5.40e+04 5.62e+05
#  8.47e+05 9.57e+05 6.88e+05 8.11e+05 2.70e+05 4.80e+04 3.29e+05 5.23e+05
#  9.21e+05 8.74e+05 9.81e+05 7.84e+05 2.80e+05 2.40e+04 5.18e+05 7.54e+05
#  8.92e+05 1.54e+05 8.60e+05 3.64e+05 3.87e+05 6.26e+05 1.61e+05 8.79e+05
#  3.90e+04 9.70e+05 1.70e+05 1.41e+05 1.60e+05 1.44e+05 1.43e+05 1.90e+05
#  3.76e+05 1.93e+05 2.46e+05 7.30e+04 6.58e+05 9.92e+05 2.53e+05 4.20e+05
#  4.04e+05 4.70e+05 2.26e+05 2.40e+05 8.90e+04 2.34e+05 2.57e+05 8.61e+05
#  4.67e+05 1.57e+05 4.40e+04 6.76e+05 6.70e+04 5.52e+05 8.85e+05 1.02e+06
#  5.82e+05 6.19e+05]

# %%
# Checking for Unique values in 'Type'
print(df['Type'].unique())
# Out:
# ['Free' 'Paid']

# %%
# Checking for Unique values in 'Installs'
print(df['Installs'].unique())
# Out:
# [     10000     500000    5000000   50000000     100000      50000
#     1000000   10000000       5000  100000000       1000  500000000
#          50        100        500         10          1          5
#  1000000000          0]

# %%
# Exporting the cleaned Dataset to a csv for further Analysis and Visualisation in MySQL and PowerBI
df.to_csv("cleaned_google_play_store_apps")

# %% [markdown]
# #**Data Visualization**

# %%
# Importing necessary libraries and packages
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# Setting default style and parameters for the Visualisations
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
# Creating barplot showing Top Categories on Google Playstore
y = df['Category'].value_counts().index
x = df['Category'].value_counts()
xsis = []
ysis = []
for i in range(len(x)):
    xsis.append(x[i])
    ysis.append(y[i])

# %%
# Creating Bar Plot showing Top Categories on Google Playstore
plt.figure(figsize=(18,13))
plt.xlabel("Count")
plt.ylabel("Category")

graph = sns.barplot(x = xsis, y = ysis, palette= "husl")
graph.set_title("Top categories on Google Playstore", fontsize = 25);

# %% [markdown]
# > **From the graph, we conclude that 'Family' is the category with the highest number of applications on Play Store.**

# %%
# Creating Bar Graph showing Content Rating by App Count
x2 = df['Content Rating'].value_counts().index
y2 = df['Content Rating'].value_counts()

x2sis = []
y2sis = []
for i in range(len(x2)):
    x2sis.append(x2[i])
    y2sis.append(y2[i])

# %%
# Creating Bar Graph showing Content Rating by App Count
plt.figure(figsize=(12,10))
plt.bar(x2sis,y2sis,width=0.8,color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2'], alpha=0.8);
plt.title('Content Rating',size = 20);
plt.ylabel('Apps(Count)');
plt.xlabel('Content Rating');

# %% [markdown]
# >**Here, we see that most apps on the Play Store are rated for 'Everyone' followed by 'Teen'.**

# %%
# Average rating of apps
avg_app_rating =df['Rating'].mean()
print('Average app rating = ', avg_app_rating)

# Creating Histogram showing Rating
df.hist(column='Rating', bins=20);
# Out:
# Average app rating =  4.206720430107526

# %% [markdown]
# >**From the above Histogram, we can infer that the majority of the ratings fall between 4 to 4.75. The average rating of an app on the Google Playstore is 4.20.**

# %%
# Creating Pie Chart showing Percent of Free vs Paid Apps in the PlayStore
plt.figure(figsize=(10,10))
labels = df['Type'].value_counts(sort = True).index
sizes = df['Type'].value_counts(sort = True)
colors = ["orange","lightblue"]
explode = (0.2,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=0)
plt.title('Percent of Free Vs Paid Apps in store',size = 20)
plt.show()

# %% [markdown]
# > **There are 92.3% of Free apps in majority and only 7.7% of Paid apps hosted on the Playstore.**

# %% [markdown]
# #**Sentiment** **Analysis**

# %%
# Readind the csv file as df2
df2 = pd.read_csv('playstore_reviews.csv')

# %%
# Dispay Top 5 rows of Dataset
df2.head()
# Out:
#                      App                                  Translated_Review
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us

# %%
# Getting information on the Dataset
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App                64295 non-null  object
#  1   Translated_Review  37427 non-null  object
# dtypes: object(2)
# memory usage: 1004.7+ KB

# %%
# Checking for null values in the Dataset
df2.isnull().sum()
# Out:
# App                      0
# Translated_Review    26868
# dtype: int64

# %%
# Finding the null values in column "Translated_Review"
df2[df2.Translated_Review.isnull()]
# Out:
#                                App Translated_Review
# 2            10 Best Foods for You               NaN
# 7            10 Best Foods for You               NaN
# 15           10 Best Foods for You               NaN
# 102          10 Best Foods for You               NaN
# 107          10 Best Foods for You               NaN
# ...                            ...               ...
# 64290  Houzz Interior Design Ideas               NaN
# 64291  Houzz Interior Design Ideas               NaN
# 64292  Houzz Interior Design Ideas               NaN
# 64293  Houzz Interior Design Ideas               NaN
# 64294  Houzz Interior Design Ideas               NaN
#
# [26868 rows x 2 columns]

# %%
# Dropping the null values in the column Translated Review
df2.dropna(subset = ['Translated_Review'], inplace = True)

# %%
# Checking for null values in the Dataset
df2.isnull().sum()
# Out:
# App                  0
# Translated_Review    0
# dtype: int64

# %%
# Creating Polarity and Subjectivity Columns and finding out the same using TextBlob
df2['polarity'] =df2['Translated_Review'].apply(lambda x: TextBlob(x).sentiment.polarity)
df2['subjectivity'] =df2['Translated_Review'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
# Displaying Top 5 rows of Dataset
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#    polarity  subjectivity
# 0      1.00      0.533333
# 1      0.25      0.288462
# 3      0.40      0.875000
# 4      1.00      0.300000
# 5      1.00      0.300000

# %%
# This function takes a polarity score as input and returns a sentiment label 
# based on the polarity score. If the polarity score is greater than 0, the 
# sentiment label is "positive". If the polarity score is equal to 0, the 
# sentiment label is "neutral". Otherwise, the sentiment label is "negative".
def classify_sentiment(polarity):
    if polarity > 0:
        return 'positive'
    elif polarity == 0:
        return 'neutral'
    else:
        return 'negative'

# Creating Sentiment Column to store the sentiment value found above for each Translated Review 'Positive', 'Neutral', 'Negative'
df2['sentiment'] = df2['polarity'].apply(lambda x: classify_sentiment(x))

# %%
# Displaying Top 5 rows of Dataset
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#    polarity  subjectivity sentiment
# 0      1.00      0.533333  positive
# 1      0.25      0.288462  positive
# 3      0.40      0.875000  positive
# 4      1.00      0.300000  positive
# 5      1.00      0.300000  positive

# %%
# Creating Scatter Plot showing Positive, Neutral and Negative Sentiment Datapoints based on Subjectivity and Polarity
# %%capture --no-display
plt.figure(figsize=(15, 10))
newcolour = {'positive' : 'blue', 'neutral': 'gray', 'negative':'red'}
sns.scatterplot(df2['polarity'], df2['subjectivity'], 
                hue = df2['sentiment'], palette= newcolour)
plt.title("Google Play Store Reviews Sentiment Analysis", fontsize=20)
plt.show()

# %% [markdown]
# >**From the above scatter plot, it can be concluded that sentiment subjectivity is directly proportional to sentiment polarity in maximum reviews. The inverted pyramid nature of the graph shows this behaviour.
# More positive/ negative reviews usually depict more personal opinion.**

# %%
# Exporting the cleaned Dataset to a csv for further Analysis and Visualisation in MySQL and PowerBI
df2.to_csv("cleaned_google_play_store_reviews")
